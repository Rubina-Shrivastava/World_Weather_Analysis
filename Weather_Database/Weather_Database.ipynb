# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime
import time

import sys
sys.path.append("..")
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
     # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
           # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        city_weather_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_weather_description})

 # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | banda aceh
# Processing Record 2 of Set 1 | kaeo
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | pampa
# Processing Record 12 of Set 1 | mayo
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | alofi
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | atkarsk
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | ambilobe
# Processing Record 24 of Set 1 | goba
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | umm lajj
# Processing Record 30 of Set 1 | sefophe
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | udachnyy
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | ilhabela
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | sao raimundo das mangabeiras
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | banepa
# Processing Record 44 of Set 1 | korla
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | belaya gora
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | ankazoabo
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | praxedis guerrero
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | praia da vitoria
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 2 | muyezerskiy
# Processing Record 7 of Set 2 | sinjhoro
# Processing Record 8 of Set 2 | narsaq
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | udomlya
# Processing Record 11 of Set 2 | manitouwadge
# Processing Record 12 of Set 2 | pervomayskoye
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | mildura
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 20 of Set 2 | sao joao da barra
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | rio grande
# Processing Record 24 of Set 2 | maumere
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | baijiantan
# Processing Record 27 of Set 2 | kawalu
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | puerto ayacucho
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | airai
# Processing Record 32 of Set 2 | aranos
# Processing Record 33 of Set 2 | sandwick
# Processing Record 34 of Set 2 | kholodnyy
# Processing Record 35 of Set 2 | kachiry
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | zelenoborskiy
# Processing Record 42 of Set 2 | synya
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | labuhan
# Processing Record 46 of Set 2 | verkhnetulomskiy
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | olga
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | the valley
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | buraydah
# Processing Record 3 of Set 3 | rafraf
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | mahibadhoo
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | teguldet
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | horodnytsya
# Processing Record 11 of Set 3 | meulaboh
# Processing Record 12 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | yambio
# Processing Record 17 of Set 3 | marawi
# Processing Record 18 of Set 3 | bacalar
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | krini
# Processing Record 21 of Set 3 | thio
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | muri
# Processing Record 24 of Set 3 | namibe
# Processing Record 25 of Set 3 | huangchuan
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | xuddur
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | pimentel
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | nurota
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | dali
# Processing Record 39 of Set 3 | makakilo city
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 3 | tazovskiy
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | porto novo
# Processing Record 46 of Set 3 | sur
# Processing Record 47 of Set 3 | carman
# Processing Record 48 of Set 3 | ise
# Processing Record 49 of Set 3 | sibolga
# Processing Record 50 of Set 3 | derzhavinsk
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | nishihara
# Processing Record 3 of Set 4 | hervey bay
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | preobrazheniye
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | hengyang
# Processing Record 9 of Set 4 | muros
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | geisenheim
# Processing Record 14 of Set 4 | kabwe
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | ketchikan
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | preeceville
# Processing Record 19 of Set 4 | contamana
# Processing Record 20 of Set 4 | abu samrah
# Processing Record 21 of Set 4 | wilmington island
# Processing Record 22 of Set 4 | moche
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | olafsvik
# Processing Record 25 of Set 4 | sept-iles
# Processing Record 26 of Set 4 | lerwick
# Processing Record 27 of Set 4 | ballina
# Processing Record 28 of Set 4 | neos pirgos
# City not found. Skipping...
# Processing Record 29 of Set 4 | manjeshwar
# Processing Record 30 of Set 4 | bairiki
# Processing Record 31 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 4 | hay river
# Processing Record 33 of Set 4 | tecolutla
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | baghmara
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | sunrise manor
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | kiruna
# Processing Record 41 of Set 4 | chuy
# Processing Record 42 of Set 4 | ribeira brava
# Processing Record 43 of Set 4 | arona
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | bonfim
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | kamaishi
# Processing Record 48 of Set 4 | sabang
# Processing Record 49 of Set 4 | ozernovskiy
# Processing Record 50 of Set 4 | abu zabad
# Processing Record 1 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 5 | lichtenburg
# Processing Record 3 of Set 5 | were ilu
# Processing Record 4 of Set 5 | mwingi
# Processing Record 5 of Set 5 | bairnsdale
# Processing Record 6 of Set 5 | rundu
# Processing Record 7 of Set 5 | ganzhou
# Processing Record 8 of Set 5 | riachao
# Processing Record 9 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 5 | fare
# Processing Record 11 of Set 5 | zhezkazgan
# Processing Record 12 of Set 5 | oistins
# Processing Record 13 of Set 5 | ulladulla
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | gunnedah
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | shimoda
# Processing Record 18 of Set 5 | luanda
# Processing Record 19 of Set 5 | port pirie
# Processing Record 20 of Set 5 | dashitou
# Processing Record 21 of Set 5 | laurel
# Processing Record 22 of Set 5 | flinders
# Processing Record 23 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 5 | urusha
# Processing Record 25 of Set 5 | prince rupert
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | erenhot
# Processing Record 28 of Set 5 | moyale
# Processing Record 29 of Set 5 | abu dhabi
# Processing Record 30 of Set 5 | kaitangata
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | nizhnyaya salda
# Processing Record 33 of Set 5 | bukama
# Processing Record 34 of Set 5 | soltsy
# Processing Record 35 of Set 5 | olivet
# Processing Record 36 of Set 5 | bilma
# Processing Record 37 of Set 5 | banposh
# Processing Record 38 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | svetlaya
# Processing Record 40 of Set 5 | northam
# Processing Record 41 of Set 5 | cheremukhovo
# Processing Record 42 of Set 5 | port lincoln
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | ekpoma
# Processing Record 45 of Set 5 | san patricio
# Processing Record 46 of Set 5 | komsomolskiy
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | saint-francois
# Processing Record 49 of Set 5 | kano
# Processing Record 50 of Set 5 | anahuac
# Processing Record 1 of Set 6 | sao miguel do guama
# Processing Record 2 of Set 6 | disna
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | kabansk
# Processing Record 5 of Set 6 | nanzhang
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | krasnyy chikoy
# Processing Record 8 of Set 6 | yumen
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | ilongero
# Processing Record 11 of Set 6 | suluq
# Processing Record 12 of Set 6 | nuuk
# Processing Record 13 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 6 | araguaina
# Processing Record 15 of Set 6 | marathon
# Processing Record 16 of Set 6 | kodiak
# Processing Record 17 of Set 6 | farrukhnagar
# Processing Record 18 of Set 6 | greeneville
# Processing Record 19 of Set 6 | lashio
# Processing Record 20 of Set 6 | vila
# Processing Record 21 of Set 6 | puerto madero
# Processing Record 22 of Set 6 | rosario do sul
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | ambon
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | tommot
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | kaele
# Processing Record 29 of Set 6 | sisimiut
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | minot
# Processing Record 32 of Set 6 | kindu
# Processing Record 33 of Set 6 | te anau
# Processing Record 34 of Set 6 | poronaysk
# Processing Record 35 of Set 6 | bud
# Processing Record 36 of Set 6 | hualmay
# Processing Record 37 of Set 6 | leshukonskoye
# Processing Record 38 of Set 6 | verkh-suetka
# Processing Record 39 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 40 of Set 6 | narasannapeta
# Processing Record 41 of Set 6 | molina
# Processing Record 42 of Set 6 | okha
# Processing Record 43 of Set 6 | santiago del estero
# Processing Record 44 of Set 6 | port macquarie
# Processing Record 45 of Set 6 | harper
# Processing Record 46 of Set 6 | sittingbourne
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | hailar
# Processing Record 49 of Set 6 | changqing
# Processing Record 50 of Set 6 | biak
# Processing Record 1 of Set 7 | altay
# Processing Record 2 of Set 7 | bethel
# Processing Record 3 of Set 7 | paita
# Processing Record 4 of Set 7 | reidsville
# Processing Record 5 of Set 7 | bathsheba
# Processing Record 6 of Set 7 | ternate
# Processing Record 7 of Set 7 | cherskiy
# Processing Record 8 of Set 7 | presidente medici
# Processing Record 9 of Set 7 | najran
# Processing Record 10 of Set 7 | bozdar
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | seoul
# Processing Record 15 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | avarua
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | malakal
# Processing Record 20 of Set 7 | tanete
# Processing Record 21 of Set 7 | araouane
# Processing Record 22 of Set 7 | lakes entrance
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | vostok
# Processing Record 25 of Set 7 | aksu
# Processing Record 26 of Set 7 | ibra
# Processing Record 27 of Set 7 | auki
# Processing Record 28 of Set 7 | kalabo
# Processing Record 29 of Set 7 | yerbogachen
# Processing Record 30 of Set 7 | yar-sale
# Processing Record 31 of Set 7 | kalvarija
# Processing Record 32 of Set 7 | rocky mountain house
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | bardiyah
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | mantiquil
# Processing Record 37 of Set 7 | alamosa
# Processing Record 38 of Set 7 | takoradi
# Processing Record 39 of Set 7 | oro valley
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | kefamenanu
# Processing Record 42 of Set 7 | sao jose da coroa grande
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | touros
# Processing Record 45 of Set 7 | binzhou
# Processing Record 46 of Set 7 | atagay
# Processing Record 47 of Set 7 | taoudenni
# Processing Record 48 of Set 7 | russell
# Processing Record 49 of Set 7 | puerto escondido
# Processing Record 50 of Set 7 | camara de lobos
# Processing Record 1 of Set 8 | north las vegas
# Processing Record 2 of Set 8 | panguna
# Processing Record 3 of Set 8 | mehamn
# Processing Record 4 of Set 8 | naqadeh
# Processing Record 5 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 6 of Set 8 | revda
# Processing Record 7 of Set 8 | palmer
# Processing Record 8 of Set 8 | reinosa
# Processing Record 9 of Set 8 | spencer
# Processing Record 10 of Set 8 | saint anthony
# Processing Record 11 of Set 8 | mamakan
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 14 of Set 8 | saint george
# Processing Record 15 of Set 8 | aswan
# Processing Record 16 of Set 8 | flin flon
# Processing Record 17 of Set 8 | vung tau
# Processing Record 18 of Set 8 | bertoua
# Processing Record 19 of Set 8 | puerto lempira
# Processing Record 20 of Set 8 | kloulklubed
# Processing Record 21 of Set 8 | jardim
# Processing Record 22 of Set 8 | askino
# Processing Record 23 of Set 8 | kryvyy rih
# Processing Record 24 of Set 8 | baruun-urt
# Processing Record 25 of Set 8 | acapulco
# Processing Record 26 of Set 8 | sao felix do xingu
# Processing Record 27 of Set 8 | inhambane
# Processing Record 28 of Set 8 | nikolayevsk-na-amure
# Processing Record 29 of Set 8 | palora
# Processing Record 30 of Set 8 | kirakira
# Processing Record 31 of Set 8 | luganville
# Processing Record 32 of Set 8 | beidao
# Processing Record 33 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 8 | greymouth
# Processing Record 35 of Set 8 | west plains
# Processing Record 36 of Set 8 | nerchinskiy zavod
# Processing Record 37 of Set 8 | ouargaye
# Processing Record 38 of Set 8 | tondano
# Processing Record 39 of Set 8 | pachino
# Processing Record 40 of Set 8 | goderich
# Processing Record 41 of Set 8 | kapoeta
# Processing Record 42 of Set 8 | aasiaat
# Processing Record 43 of Set 8 | namtsy
# Processing Record 44 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 8 | mindelo
# Processing Record 46 of Set 8 | praia
# Processing Record 47 of Set 8 | clyde river
# Processing Record 48 of Set 8 | areia branca
# Processing Record 49 of Set 8 | karonga
# Processing Record 50 of Set 8 | shingu
# Processing Record 1 of Set 9 | burnie
# Processing Record 2 of Set 9 | kalmunai
# Processing Record 3 of Set 9 | itarema
# Processing Record 4 of Set 9 | faanui
# Processing Record 5 of Set 9 | naushahro firoz
# Processing Record 6 of Set 9 | gamba
# Processing Record 7 of Set 9 | otjimbingwe
# Processing Record 8 of Set 9 | saint-georges
# Processing Record 9 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 9 | novopokrovka
# Processing Record 11 of Set 9 | tiksi
# Processing Record 12 of Set 9 | charyshskoye
# Processing Record 13 of Set 9 | taywarah
# Processing Record 14 of Set 9 | holetown
# Processing Record 15 of Set 9 | broken hill
# Processing Record 16 of Set 9 | san vicente
# Processing Record 17 of Set 9 | chase
# Processing Record 18 of Set 9 | alta floresta
# Processing Record 19 of Set 9 | novoseleznevo
# Processing Record 20 of Set 9 | los llanos de aridane
# Processing Record 21 of Set 9 | kristinehamn
# Processing Record 22 of Set 9 | gornyy
# Processing Record 23 of Set 9 | hunfeld
# Processing Record 24 of Set 9 | kalianget
# Processing Record 25 of Set 9 | vyazemskiy
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | coihaique
# Processing Record 28 of Set 9 | hami
# Processing Record 29 of Set 9 | flagstaff
# Processing Record 30 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 9 | san juan
# Processing Record 32 of Set 9 | ruwi
# Processing Record 33 of Set 9 | lucea
# Processing Record 34 of Set 9 | kahului
# Processing Record 35 of Set 9 | kamenka
# Processing Record 36 of Set 9 | romny
# Processing Record 37 of Set 9 | bara
# Processing Record 38 of Set 9 | channel-port aux basques
# Processing Record 39 of Set 9 | lompoc
# Processing Record 40 of Set 9 | ferrol
# Processing Record 41 of Set 9 | bodmin
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | sibu
# Processing Record 44 of Set 9 | mitsamiouli
# Processing Record 45 of Set 9 | pimenta bueno
# Processing Record 46 of Set 9 | oranjestad
# Processing Record 47 of Set 9 | druzhinino
# Processing Record 48 of Set 9 | atar
# Processing Record 49 of Set 9 | manzil salim
# Processing Record 50 of Set 9 | sao filipe
# Processing Record 1 of Set 10 | tura
# Processing Record 2 of Set 10 | chicama
# Processing Record 3 of Set 10 | riviere-du-loup
# Processing Record 4 of Set 10 | griffith
# Processing Record 5 of Set 10 | champerico
# Processing Record 6 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 7 of Set 10 | tabas
# Processing Record 8 of Set 10 | arman
# Processing Record 9 of Set 10 | augustow
# Processing Record 10 of Set 10 | san quintin
# Processing Record 11 of Set 10 | nhulunbuy
# Processing Record 12 of Set 10 | kathmandu
# Processing Record 13 of Set 10 | varazdin
# Processing Record 14 of Set 10 | calbuco
# Processing Record 15 of Set 10 | rehoboth
# Processing Record 16 of Set 10 | penzance
# Processing Record 17 of Set 10 | ust-maya
# Processing Record 18 of Set 10 | fort nelson
# Processing Record 19 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | alice springs
# Processing Record 21 of Set 10 | laguna
# Processing Record 22 of Set 10 | alindao
# Processing Record 23 of Set 10 | innisfail
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | boyolangu
# Processing Record 26 of Set 10 | ilanskiy
# Processing Record 27 of Set 10 | arroyo
# Processing Record 28 of Set 10 | egersund
# Processing Record 29 of Set 10 | corum
# Processing Record 30 of Set 10 | turayf
# Processing Record 31 of Set 10 | kimbe
# Processing Record 32 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 33 of Set 10 | clarksburg
# Processing Record 34 of Set 10 | dabola
# Processing Record 35 of Set 10 | abha
# Processing Record 36 of Set 10 | gondar
# Processing Record 37 of Set 10 | nyurba
# Processing Record 38 of Set 10 | halifax
# Processing Record 39 of Set 10 | nara
# Processing Record 40 of Set 10 | caruray
# Processing Record 41 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 42 of Set 10 | nioro
# Processing Record 43 of Set 10 | oussouye
# Processing Record 44 of Set 10 | mayor pablo lagerenza
# Processing Record 45 of Set 10 | katsuura
# Processing Record 46 of Set 10 | valparaiso
# Processing Record 47 of Set 10 | zeya
# Processing Record 48 of Set 10 | kozhevnikovo
# Processing Record 49 of Set 10 | winchester
# Processing Record 50 of Set 10 | braganca
# Processing Record 1 of Set 11 | kunming
# Processing Record 2 of Set 11 | virginia beach
# Processing Record 3 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 11 | grevena
# Processing Record 5 of Set 11 | raduzhnyy
# Processing Record 6 of Set 11 | haines junction
# Processing Record 7 of Set 11 | souillac
# Processing Record 8 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 11 | hovd
# Processing Record 10 of Set 11 | mount vernon
# Processing Record 11 of Set 11 | omboue
# Processing Record 12 of Set 11 | mecca
# Processing Record 13 of Set 11 | minab
# Processing Record 14 of Set 11 | kutum
# Processing Record 15 of Set 11 | baker city
# Processing Record 16 of Set 11 | benemerito de las americas
# Processing Record 17 of Set 11 | fonte boa
# Processing Record 18 of Set 11 | sao francisco do sul
# Processing Record 19 of Set 11 | tual
# Processing Record 20 of Set 11 | thoen
# Processing Record 21 of Set 11 | katherine
# Processing Record 22 of Set 11 | ajdabiya
# Processing Record 23 of Set 11 | matara
# Processing Record 24 of Set 11 | guarapari
# Processing Record 25 of Set 11 | vardo
# Processing Record 26 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 11 | pisco
# Processing Record 28 of Set 11 | patos
# Processing Record 29 of Set 11 | lesnyye polyany
# Processing Record 30 of Set 11 | caohai
# Processing Record 31 of Set 11 | emerald
# Processing Record 32 of Set 11 | san diego de los banos
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 11 | la ronge
# Processing Record 36 of Set 11 | mapiri
# Processing Record 37 of Set 11 | eyl
# Processing Record 38 of Set 11 | cedar city
# Processing Record 39 of Set 11 | manicore
# Processing Record 40 of Set 11 | morant bay
# Processing Record 41 of Set 11 | maamba
# Processing Record 42 of Set 11 | tateyama
# Processing Record 43 of Set 11 | kiunga
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | tupaciguara
# Processing Record 46 of Set 11 | gizo
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | cayenne
# Processing Record 49 of Set 11 | perpignan
# Processing Record 50 of Set 11 | brandon
# Processing Record 1 of Set 12 | jiangdu
# Processing Record 2 of Set 12 | alyangula
# Processing Record 3 of Set 12 | verdalsora
# City not found. Skipping...
# Processing Record 4 of Set 12 | honiara
# Processing Record 5 of Set 12 | iskateley
# Processing Record 6 of Set 12 | sosnovo-ozerskoye
# Processing Record 7 of Set 12 | bosaso
# Processing Record 8 of Set 12 | susani
# Processing Record 9 of Set 12 | kirksville
# Processing Record 10 of Set 12 | vila velha
# Processing Record 11 of Set 12 | mangrol
# Processing Record 12 of Set 12 | verneuil-sur-seine
# Processing Record 13 of Set 12 | buala
# Processing Record 14 of Set 12 | pahrump
# Processing Record 15 of Set 12 | tocopilla
# Processing Record 16 of Set 12 | baghdad
# Processing Record 17 of Set 12 | pochutla
# Processing Record 18 of Set 12 | marfino
# Processing Record 19 of Set 12 | balkhash
# Processing Record 20 of Set 12 | port augusta
# Processing Record 21 of Set 12 | wahiawa
# Processing Record 22 of Set 12 | khandyga
# Processing Record 23 of Set 12 | rudbar
# Processing Record 24 of Set 12 | manado
# Processing Record 25 of Set 12 | yulara
# Processing Record 26 of Set 12 | avera
# Processing Record 27 of Set 12 | sobolevo
# Processing Record 28 of Set 12 | quatre cocos
# Processing Record 29 of Set 12 | luau
# Processing Record 30 of Set 12 | mala vyska
# Processing Record 31 of Set 12 | lubao
# Processing Record 32 of Set 12 | severnyy-kospashskiy
# Processing Record 33 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | sumbe
# Processing Record 36 of Set 12 | taltal
# Processing Record 37 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 38 of Set 12 | batticaloa
# Processing Record 39 of Set 12 | djenne
# Processing Record 40 of Set 12 | bowen
# Processing Record 41 of Set 12 | thunder bay
# Processing Record 42 of Set 12 | palauig
# Processing Record 43 of Set 12 | henties bay
# Processing Record 44 of Set 12 | savannakhet
# Processing Record 45 of Set 12 | esperance
# Processing Record 46 of Set 12 | darhan
# Processing Record 47 of Set 12 | titlagarh
# Processing Record 48 of Set 12 | eureka
# Processing Record 49 of Set 12 | kandalaksha
# Processing Record 50 of Set 12 | banjarmasin
# Processing Record 1 of Set 13 | lesozavodsk
# Processing Record 2 of Set 13 | lere
# Processing Record 3 of Set 13 | santo tomas
# Processing Record 4 of Set 13 | artesia
# Processing Record 5 of Set 13 | istok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_data_df = pd.DataFrame(city_data)
new_city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Banda Aceh   5.5577   95.3222     79.16        84         100
# 1            Kaeo -35.1000  173.7833     56.32        97         100
# 2       Saskylakh  71.9167  114.0833     48.31        57          99
# 3        Tasiilaq  65.6145  -37.6368     39.36        79          17
# 4           Bluff -46.6000  168.3333     43.81        77          97
# 5  Saint-Philippe -21.3585   55.7679     65.79        80          27
# 6         Qaanaaq  77.4840  -69.3632     38.73        96         100
# 7       Hithadhoo  -0.6000   73.0833     83.03        73          92
# 8       Cape Town -33.9258   18.4232     57.88        93         100
# 9     Provideniya  64.3833 -173.3000     51.91        76         100
#
#    Wind Speed Country                 Date Current Description
# 0        8.95      ID  2022-07-13 22:38:36     overcast clouds
# 1        7.65      NZ  2022-07-13 22:36:38          light rain
# 2       10.76      RU  2022-07-13 22:38:36     overcast clouds
# 3        4.59      GL  2022-07-13 22:38:36          few clouds
# 4       10.22      NZ  2022-07-13 22:38:37     overcast clouds
# 5       10.27      RE  2022-07-13 22:35:24          light rain
# 6        6.40      GL  2022-07-13 22:38:37          light rain
# 7       13.58      MV  2022-07-13 22:38:38     overcast clouds
# 8       16.11      ZA  2022-07-13 22:33:58       moderate rain
# 9       11.18      RU  2022-07-13 22:38:38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
